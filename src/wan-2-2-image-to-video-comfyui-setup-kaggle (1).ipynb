# %% [markdown]
# # Install ComfyUI and dependencies

# %%
# Install ComfyUI and dependencies
# !pip install -q torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install -q huggingface_hub
# !mkdir -p /kaggle/tmp
# !git clone https://github.com/comfyanonymous/ComfyUI.git /kaggle/tmp/ComfyUI
# %cd /kaggle/tmp/ComfyUI
# !pip install -q -r requirements.txt

# Install ComfyUI-Manager
# !git clone https://github.com/ltdrdata/ComfyUI-Manager.git custom_nodes/ComfyUI-Manager

    
# Install ComfyUI-KJNodes (helper nodes used in the official LTX-2.3 GGUF workflow)
# !git clone https://github.com/kijai/ComfyUI-KJNodes.git custom_nodes/ComfyUI-KJNodes
# !pip install -q -r custom_nodes/ComfyUI-KJNodes/requirements.txt

# Install the missing GGUF loader custom node
# !git clone https://github.com/city96/ComfyUI-GGUF.git custom_nodes/ComfyUI-GGUF
# %cd /kaggle/tmp/ComfyUI/custom_nodes/ComfyUI-GGUF

# 1. Install required python libraries for GGUF parsing
# !pip install -q -r requirements.txt
# !pip install -q gguf sentencepiece

print("\nGGUF library dependencies successfully patched!")
# !git clone https://github.com/Kosinkadink/ComfyUI-VideoHelperSuite.git custom_nodes/ComfyUI-VideoHelperSuite
# 1. Move into the video helper suite directory
# %cd /kaggle/tmp/ComfyUI/custom_nodes/ComfyUI-VideoHelperSuite

# 2. Force install the required system and video manipulation libraries
# !pip install -q -r requirements.txt
# !pip install -q decord av simplejson imageio-ffmpeg

# Install cloudflared to expose the URL publicly
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64 -O cloudflared
# !chmod +x cloudflared


# %cd /kaggle/tmp/ComfyUI
# Out:
# Cloning into '/kaggle/tmp/ComfyUI'...
# remote: Enumerating objects: 42712, done.
# remote: Counting objects: 100% (140/140), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 42712 (delta 126), reused 106 (delta 106), pack-reused 42572 (from 2)
# Receiving objects: 100% (42712/42712), 83.68 MiB | 23.99 MiB/s, done.
# Resolving deltas: 100% (28959/28959), done.
# /kaggle/tmp/ComfyUI
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.6/26.6 MB 67.6 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 93.5 MB/s eta 0:00:00:00:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 107.3 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.8/346.8 kB 25.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 74.3 MB/s eta 0:00:00:00:01
# ...

# %% [markdown]
# # Download models

# %%
# %cd /kaggle/tmp/ComfyUI

# 3. Create the required directory for clip_vision models
# !mkdir -p models/clip_vision
# Create standard target directories
# !mkdir -p models/unet
# !mkdir -p models/text_encoders
# !mkdir -p models/vae
# !mkdir -p models/clip_vision


# Use huggingface_hub to fetch your chosen befox GGUF model paths
from huggingface_hub import hf_hub_download


print("Downloading clip_vision_h.safetensors from the correct repository...")
hf_hub_download(
    repo_id="Comfy-Org/Wan_2.1_ComfyUI_repackaged",  # Switched repo path
    filename="split_files/clip_vision/clip_vision_h.safetensors",
    local_dir="models/clip_vision",
    local_dir_use_symlinks=False
)

print("Downloading the correct Image-to-Video (I2V) GGUF file...")
hf_hub_download(
    repo_id="befox/WAN2.2-14B-Rapid-AllInOne-GGUF",
    filename="v10/wan2.2-i2v-rapid-aio-v10-nsfw-Q4_K.gguf", # Notice the i2v swap here
    local_dir="models/unet",
    local_dir_use_symlinks=False
)

print("Downloading Wan 2.1 VAE...")
hf_hub_download(
    repo_id="Comfy-Org/Wan_2.2_ComfyUI_Repackaged",
    filename="split_files/vae/wan_2.1_vae.safetensors",
    local_dir="models/vae",
    local_dir_use_symlinks=False
)

print("Downloading Text Encoder...")
hf_hub_download(
    repo_id="Comfy-Org/Wan_2.1_ComfyUI_repackaged",
    filename="split_files/text_encoders/umt5_xxl_fp8_e4m3fn_scaled.safetensors",
    local_dir="models/text_encoders",
    local_dir_use_symlinks=False
)

print("All set! Files successfully downloaded to /kaggle/tmp/ComfyUI/models/.")
# Out:
# /kaggle/tmp/ComfyUI
# ...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:205: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `hf_hub_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# ...
# split_files/clip_vision/clip_vision_h.sa(…):   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# ...
# v10/wan2.2-i2v-rapid-aio-v10-nsfw-Q4_K.g(…):   0%|          | 0.00/10.8G [00:00<?, ?B/s]
# ...
# split_files/vae/wan_2.1_vae.safetensors:   0%|          | 0.00/254M [00:00<?, ?B/s]
# ...
# split_files/text_encoders/umt5_xxl_fp8_e(…):   0%|          | 0.00/6.74G [00:00<?, ?B/s]
# All set! Files successfully downloaded to /kaggle/tmp/ComfyUI/models/.

# %% [markdown]
# # Install cloudflared for the tunnel public URL for the comfy UI

# %%
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64 -O /kaggle/tmp/cloudflared
# !chmod +x /kaggle/tmp/cloudflared
# !ls -lh /kaggle/tmp/cloudflared
# Out:
# -rwxr-xr-x 1 root root 38M Jun 18 14:40 /kaggle/tmp/cloudflared

# %% [markdown]
# # Start Comfy UI

# %%
import subprocess, time
    
# Added the --enable-manager flag and forced custom node checking
proc = subprocess.Popen(["python", "main.py", "--listen", "0.0.0.0", "--port", "8182", "--enable-manager"])
time.sleep(5)
# Out:
# [INFO] setup plugin alembic.autogenerate.schemas
# [INFO] setup plugin alembic.autogenerate.tables
# [INFO] setup plugin alembic.autogenerate.types
# [INFO] setup plugin alembic.autogenerate.constraints
# [INFO] setup plugin alembic.autogenerate.defaults
# [INFO] setup plugin alembic.autogenerate.comments
# [WARNING]
#
# To use the `--enable-manager` feature, the `comfyui-manager` package must be installed first.
# command:
# 	/usr/bin/python3 -m pip install -r /kaggle/tmp/ComfyUI/manager_requirements.txt
# or using uv:
# 	uv pip install -r /kaggle/tmp/ComfyUI/manager_requirements.txt
# FETCH ComfyRegistry Data: 5/159
# [START] Security scan
# [DONE] Security scan
# ## ComfyUI-Manager: installing dependencies done.
# ** ComfyUI startup time: 2026-07-05 07:55:08.756
# ** Platform: Linux
# ** Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# ** Python executable: /usr/bin/python3
# ** ComfyUI Path: /kaggle/tmp/ComfyUI
# ...

# %% [markdown]
# # Create tunnel and get URL

# %%
import subprocess

tunnel = subprocess.Popen(
    ["/kaggle/tmp/cloudflared", "tunnel", "--url", "http://localhost:8182"],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT
)

print("Waiting for URL... (may take 15-20 seconds)")
for line in iter(tunnel.stdout.readline, b""):
    line = line.decode().strip()
    print(line)
    if "https://" in line and "trycloudflare.com" in line:
        for word in line.split():
            if word.startswith("https://") and "trycloudflare.com" in word:
                print("\n\u2705 Your ComfyUI URL:", word)
                break
        break
# Out:
# Waiting for URL... (may take 15-20 seconds)
# 2026-07-05T07:54:14Z INF Thank you for trying Cloudflare Tunnel. Doing so, without a Cloudflare account, is a quick way to experiment and try it out. However, be aware that these account-less Tunnels have no uptime guarantee, are subject to the Cloudflare Online Services Terms of Use (https://www.cloudflare.com/website-terms/), and Cloudflare reserves the right to investigate your use of Tunnels for violations of such terms. If you intend to use Tunnels in production you should use a pre-created named tunnel by following: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps
# 2026-07-05T07:54:14Z INF Requesting new quick Tunnel on trycloudflare.com...
# [START] Security scan
# [DONE] Security scan
# ## ComfyUI-Manager: installing dependencies done.
# ** ComfyUI startup time: 2026-07-05 07:54:15.358
# ** Platform: Linux
# ** Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# ...
